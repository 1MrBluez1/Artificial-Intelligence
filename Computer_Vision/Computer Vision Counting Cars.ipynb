# %% [markdown]
# # Computer Vison
#
# ### Determine the numbers of cars and trucks in the Image using cvlib
#
# You may need to install cvlib using the command line and pip install cvlib.
#
# Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly
from PIL import Image

# %%
# Load image
path = r'C:\Users\Gandalf\MY PROJECTS\cars.jpeg'

# %%
#Check the image using PIL to ensure it is loading correctly
img = Image.open('cars.jpeg')
img.show()

# %%
#Use cv2 to analyze image for cars and trucks then display results
image = cv2.imread(path)
bbox, label, conf = cv.detect_common_objects(image)
output = draw_bbox(image, bbox, label, conf)
plt.imshow(output)
plt.show()
print("Number of cars in this image are " +str(label.count('car')), "and the number of trucks are " +str(label.count('truck')))
# Out:
# Number of cars in this image are 11 and the number of trucks are 3
